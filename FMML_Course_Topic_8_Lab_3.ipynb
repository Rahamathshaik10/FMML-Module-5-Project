# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahamathshaik10/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 15:31:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   227MB/s    in 0.3s
#
# 2024-03-28 15:31:37 (227 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20639  1608.08072v1  Multimedia reasoning, which is suitable for, a...    cs
# 828    1706.02275v3  We explore deep reinforcement learning methods...    cs
# 22954  1711.08374v1  In this paper, a scale mixture of Normal distr...  stat
# 10813   1405.5869v1  We present the first provably sublinear time a...  stat
# 11931  1704.03711v1  Hidden Markov Models (HMMs) are a ubiquitous t...  stat
# ...             ...                                                ...   ...
# 22075   1410.3192v1  We study prediction and estimation problems us...  stat
# 4314   1604.00974v1  Automatic Offline Handwritten Signature Verifi...    cs
# 25183  1506.04051v1  Given a set of images of a scene taken at diff...    cs
# 26466  1610.06987v1  Statistical models have been successful in acc...    cs
# 22803  1707.02780v1  We develop a model in which interactions betwe...  stat
#
#                                                    title  year  \
# 20639  A Novel Approach to Multimedia Ontology Engine...  2016
# 828    Multi-Agent Actor-Critic for Mixed Cooperative...  2017
# 22954  Variational Bayesian Inference For A Scale Mix...  2017
# 10813  Asymmetric LSH (ALSH) for Sublinear Time Maxim...  2014
# 11931  Investigation on the use of Hidden-Markov Mode...  2017
# ...                                                  ...   ...
# 22075  Learning without Concentration for General Los...  2014
# 4314   Writer-independent Feature Learning for Offlin...  2016
# 25183  Towards Benchmarking Scene Background Initiali...  2015
# 26466  Multitask Learning of Vegetation Biochemistry ...  2016
# 22803  Block modelling in dynamic networks with non-h...  2017
#
#                                                 keywords
# 20639  [multimedia, reasoning, multimedia, interpreta...
# 828    [reinforcement, analyzing, difficulty, traditi...
# 22954  [distributions, developed, classification, clu...
# 10813  [sublinear, algorithm, approximate, emphmaximu...
# 11931  [ubiquitous, automatic, transcription, segment...
# ...                                                  ...
# 22075  [prediction, estimation, empirical, minimizati...
# 4314   [automatic, handwritten, signature, verificati...
# 25183  [different, availability, background, describe...
# 26466  [statistical, successful, accurately, estimati...
# 22803  [interactions, homogeneous, processes, modelli...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20639    [multimedia, reasoning, multimedia, interpreta...
# 828      [reinforcement, analyzing, difficulty, traditi...
# 22954    [distributions, developed, classification, clu...
# 10813    [sublinear, algorithm, approximate, emphmaximu...
# 11931    [ubiquitous, automatic, transcription, segment...
#                                ...
# 29735    [provision, information, essential, accidents,...
# 24428    [conducted, determine, thickness, coherence, t...
# 10570    [clustering, histograms, important, ingredient...
# 21334    [developments, established, vulnerability, rei...
# 7610     [tractable, information, contained, generative...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8805 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95d8e04d-fe46-4bbd-819d-08c0d528bc25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95d8e04d-fe46-4bbd-819d-08c0d528bc25")) {                    Plotly.newPlot(                        "95d8e04d-fe46-4bbd-819d-08c0d528bc25",                        [{"x":["interdependencies","interpretation","conceptualization","description","engineering","definitions","exhaustive","introduced","audiovisual","incorporate","multimedia","ontologies","generation","reasoners","expressivity","expressive","reasoning","implement","knowledge","application","comprehensive","inclusions","automated","available","grounding","validated","consequently","represented","developing","practices","considers","populations","strategies","successfully","traditional","environment","coordination","challenged","reinforcement","adaptation","scenarios","increases","stationarity","analyzing","algorithms","introduce","informational","cooperative","additionally","utilizing","environments","competitive","difficulty","introduction","variables","approximation","distributions","clustering","classification","possibility","processed","treatment","supervised","modelling","inference","developed","variational","restrictive","sensitivity","filtering","underlying","algorithm","efficient","sensitive","movielens","asymmetric","theoretical","retrieving","sublinear","transformations","converted","collaborative","construction","insufficient","searching","mathematical","phenomenon","observation","framework","independent","approximate","recommendations","considered","similarity","interesting","automatic","correcting","different","comparatively","improvements","ubiquitous","depending","integrating","instrument","investigation","evaluated","noticeable","segmentation","repertoire","component","identifying","transcription","sequential","polyphonic","repertoires","estimation","including","probabilistic","processing","transitions","candidate","enforcing","deterministic","properties","violating","generates","continuous","improving","requiring","constituency","procedure","satisfies","syntactic","expensive","increasingly","constraints","structures","performing","applications","practitioners","unconstrained","experimental","spherical","performed","preliminary","capability","reconstructed","simulation","maximization","simultaneous","algebraic","tomographic","likelihood","investigated","information","technique","projection","reconstruction","expectation","identifiable","simulated","dimensional","radiation","detection","demonstrated","simultaneously","multitask","generative","combination","representation","demonstrate","specifically","objectives","performance","benchmark","effectiveness","discriminative","relationship","formulated","technical","multiclass","optimization","regarding","conditions","revisions","connection","syntactical","particular","preferences","preserved","controversy","controversial","counterexamples","intuitions","additional","intuition","mentioned","postulate","similarities","postulates"],"y":[4,50,2,69,50,25,17,116,5,67,8,19,140,3,6,28,125,68,352,221,61,2,85,318,6,43,31,90,48,11,40,13,100,77,183,132,9,6,110,65,83,46,2,62,563,354,4,8,69,51,87,121,38,22,122,120,112,117,488,33,27,36,213,50,219,186,56,11,33,59,139,838,428,63,2,10,154,15,8,43,9,25,71,14,28,54,20,59,543,121,115,28,124,160,77,211,7,734,7,102,17,30,46,2,41,135,5,200,0,101,64,8,73,2,1,204,243,173,250,9,32,11,38,206,2,48,118,106,46,5,115,10,65,67,51,142,130,88,465,9,20,376,8,119,48,55,21,85,21,32,14,2,66,47,733,233,50,87,24,7,68,187,7,365,98,107,8,119,152,347,588,186,23,914,224,201,89,68,32,38,7,320,34,144,3,33,3,257,40,15,2,2,4,3,104,14,18,2,40,3],"type":"bar"},{"x":["interdependencies","interpretation","conceptualiza ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Enriching</span> <span style=''>Frame</span> <span style='background-color:rgba(0, 255, 0, 0.4761904761904763);'>Representations</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>Distributionally</span> <span style=''>Induced</span> <span style=''>Senses</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>lexical</span> <span style=''>resource</span> <span style=''>that</span> <span style=''>enriches</span> <span style=''>the</span> <span style=''>Framester</span> <span style='background-color:rgba(0, 255, 0, 0.3512476007677544);'>knowledge</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>links</span> <span style=''>Framnet</span> <span style=''>WordNet</span> <span style=''>VerbNet</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.44186046511627913);'>resources</span> <span style=''>with</span> <span style=''>semantic</span> <span style=''>features</span> <span style=''>from</span> <span style=''>text</span> <span style=''>corpora</span> <span style=''>These</span> <span style=''>features</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.6488549618320612);'>extracted</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>distributionally</span> <span style=''>induced</span> <span style=''>sense</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inventories</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>the</span> <span style=''>manually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>frame</span> <span style='background-color:rgba(0, 255, 0, 0.4761904761904763);'>representations</span> <span style=''>to</span> <span style=''>boost</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>frame</span> <span style='background-color:rgba(0, 255, 0, 0.9047619047619049);'>disambiguation</span> <span style=''>in</span> <span style=''>context</span> <span style=''>Since</span> <span style=''>Framester</span> <span style=''>is</span> <span style=''>a</span> <span style=''>frame</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3512476007677544);'>knowledge</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>full</span> <span style=''>fledged</span> <span style=''>OWL</span> <span style=''>querying</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7482517482517483);'>reasoning</span> <span style=''>our</span> <span style=''>resource</span> <span style=''>paves</span> <span style=''>the</span> <span style=''>way</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.45121951219512196);'>development</span> <span style=''>of</span> <span style=''>novel</span> <span style=''>deeper</span> <span style=''>semantic</span> <span style=''>aware</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>that</span> <span style=''>could</span> <span style=''>benefit</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3755656108597285);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3512476007677544);'>knowledge</span> <span style=''>from</span> <span style=''>text</span> <span style=''>and</span> <span style=''>complex</span> <span style=''>symbolic</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Certifiably</span> <span style=''>Optimal</span> <span style=''>Rule</span> <span style=''>Lists</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Categorical</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>design</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>custom</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>building</span> <span style=''>rule</span> <span style=''>lists</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>categorical</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>produces</span> <span style=''>rule</span> <span style=''>lists</span> <span style=''>with</span> <span style=''>optimal</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>certificate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimality</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style=''>bounds</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>reuse</span> <span style=''>we</span> <span style=''>achieve</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>speedup</span> <span style=''>in</span> <span style=''>time</span> <span style=''>and</span> <span style=''>a</span> <span style=''>massive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumption</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>produces</span> <span style=''>optimal</span> <span style=''>rule</span> <span style=''>lists</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>seconds</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>optimal</span> <span style=''>sparse</span> <span style=''>rule</span> <span style=''>lists</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>as</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Consistent</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999986);'>Multilabel</span> <span style=''>Ranking</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666667);'>Univariate</span> <span style=''>Losses</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>rank</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>in</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999986);'>multilabel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>which</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>tackled</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>losses</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>labels</span> <span style=''>Very</span> <span style=''>recently</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>was</span> <span style=''>put</span> <span style=''>into</span> <span style=''>question</span> <span style=''>by</span> <span style=''>a</span> <span style=''>negative</span> <span style=''>result</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>losses</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>and</span> <span style=''>logistic</span> <span style=''>losses</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>inconsistent</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>a</span> <span style=''>positive</span> <span style=''>result</span> <span style=''>which</span> <span style=''>is</span> <span style=''>arguably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprising</span> <span style=''>in</span> <span style=''>light</span> <span style=''>of</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>one</span> <span style=''>the</span> <span style=''>simpler</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666667);'>univariate</span> <span style=''>variants</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>and</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>surrogates</span> <span style=''>(ie</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>single</span> <span style=''>labels)</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>rank</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>directly</span> <span style=''>proving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>much</span> <span style=''>stronger</span> <span style=''>result</span> <span style=''>by</span> <span style=''>deriving</span> <span style=''>regret</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Closer</span> <span style=''>Look</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Memorization</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>role</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>memorization</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>drawing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connections</span> <span style=''>to</span> <span style=''>capacity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>While</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>memorizing</span> <span style=''>noise</span> <span style=''>data</span> <span style=''>our</span> <span style=''>results</span> <span style=''>suggest</span> <span style=''>that</span> <span style=''>they</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>prioritize</span> <span style=''>learning</span> <span style=''>simple</span> <span style=''>patterns</span> <span style=''>first</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style=''>expose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>in</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNNs)</span> <span style=''>on</span> <span style=''>noise</span> <span style=''>vs</span> <span style=''>real</span> <span style=''>data</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriately</span> <span style=''>tuned</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>(eg</span> <span style=''>dropout)</span> <span style=''>we</span> <span style=''>can</span> <span style=''>degrade</span> <span style=''>DNN</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>noise</span> <span style=''>datasets</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compromising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>on</span> <span style=''>real</span> <span style=''>data</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>the</span> <span style=''>notions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>capacity</span> <span style=''>which</span> <span style=''>are</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>are</span> <span style=''>unlikely</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizatio ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representations (0.08750882145377559)
# 	automatic (0.0744530698659139)
# 	experimental (0.13267466478475654)
# 	architecture (0.08750882145377559)
# 	segmentation (0.07057163020465773)
# 	different (0.2589978828510939)
# 	information (0.25864502470007056)
# 	detection (0.12879322512350036)
# 	convolutional (0.13126323218066338)
# 	recognition (0.13161609033168667)
#
# Some Statistics words are:
# 	algorithms (0.2807731434384537)
# 	statistical (0.15564598168870802)
# 	theoretical (0.16022380467955238)
# 	variables (0.14903357070193285)
# 	algorithm (0.40284842319430314)
# 	estimation (0.18311291963377416)
# 	distribution (0.19023397761953204)
# 	inference (0.20396744659206512)
# 	regression (0.1775178026449644)
# 	dimensional (0.2029501525940997)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f32bec98-8975-41d1-aaf5-bec6a40d6ae8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f32bec98-8975-41d1-aaf5-bec6a40d6ae8")) {                    Plotly.newPlot(                        "f32bec98-8975-41d1-aaf5-bec6a40d6ae8",                        [{"x":["interdependencies","interpretation","conceptualization","description","engineering","definitions","exhaustive","introduced","audiovisual","incorporate","multimedia","ontologies","generation","reasoners","expressivity","expressive","reasoning","implement","knowledge","application","comprehensive","inclusions","automated","available","grounding","validated","consequently","represented","developing","practices","considers","populations","strategies","successfully","traditional","environment","coordination","challenged","reinforcement","adaptation","scenarios","increases","stationarity","analyzing","algorithms","introduce","informational","cooperative","additionally","utilizing","environments","competitive","difficulty","introduction","variables","approximation","distributions","clustering","classification","possibility","processed","treatment","supervised","modelling","inference","developed","variational","restrictive","sensitivity","filtering","underlying","algorithm","efficient","sensitive","movielens","asymmetric","theoretical","retrieving","sublinear","transformations","converted","collaborative","construction","insufficient","searching","mathematical","phenomenon","observation","framework","independent","approximate","recommendations","considered","similarity","interesting","automatic","correcting","different","comparatively","improvements","ubiquitous","depending","integrating","instrument","investigation","evaluated","noticeable","segmentation","repertoire","component","identifying","transcription","sequential","polyphonic","repertoires","estimation","including","probabilistic","processing","transitions","candidate","enforcing","deterministic","properties","violating","generates","continuous","improving","requiring","constituency","procedure","satisfies","syntactic","expensive","increasingly","constraints","structures","performing","applications","practitioners","unconstrained","experimental","spherical","performed","preliminary","capability","reconstructed","simulation","maximization","simultaneous","algebraic","tomographic","likelihood","investigated","information","technique","projection","reconstruction","expectation","identifiable","simulated","dimensional","radiation","detection","demonstrated","simultaneously","multitask","generative","combination","representation","demonstrate","specifically","objectives","performance","benchmark","effectiveness","discriminative","relationship","formulated","technical","multiclass","optimization","regarding","conditions","revisions","connection","syntactical","particular","preferences","preserved","controversy","controversial","counterexamples","intuitions","additional","intuition","mentioned","postulate","similarities","postulates","capturing","epistemic","introduces","previously","parametrisation","regularisation","evaluation","solutions","discussed","publications","directions","analytical","extensions","generally","posterior","multiplicative","overfitting","arguments","implications","perspective","correlated","explained","stochastic","reinterpreted","objective","inferring","uncertainty","parameter","techniques","semisupervised","increased","components","following","flexibility","estimates","important","transition","manipulation","convolutional","containing","generated","synthetic","significant","classified","compositing","detections","improvement","synthetically","computations","comparison","outperform","riemannian","b ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	repertoire
# 	parametrisation
# 	collinearity
# 	sparsifies
# 	inspecting
# 	disregard
# 	nucleotide
# 	changepoint
# 	frequentist
# 	archetypal
# 	archetypes
# 	necessitate
# 	descendant
# 	prominently
# 	increments
# 	penalization
# 	lancaster
# 	geostatistical
# 	liblinear
# 	hermitian
# Some words which never appear in Statistics papers:
# 	conceptualization
# 	reasoners
# 	grounding
# 	informational
# 	constituency
# 	syntactic
# 	revisions
# 	syntactical
# 	controversy
# 	postulates
# 	manipulation
# 	compositing
# 	sigmoidal
# 	abstracting
# 	sacrifices
# 	neutrality
# 	evolvability
# 	interlocutors
# 	conversational
# 	instructions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0398832684824907e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7375
